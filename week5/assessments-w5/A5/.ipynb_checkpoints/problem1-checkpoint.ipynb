# %% [markdown]
# # Python for Data Science Bootcamp
# ## Assignment 4
#
# NOTE: This assignment has 3 problems.  Please write your code in the designated portion of the autograded answer cell.
#
# For this problem set, we'll be using the Jupyter notebook and nbgrader:
#
# ![](jupyter.png)
#
# ©2020 Luis Morales. All rights reserved.

# %% [markdown]
# ## Problem 1 (1 point)
#
# Go to https://matplotlib.org/gallery/index.html, pick two nontrival examples, digest them and illustrate in the following cell. You need write annotation and explantion for each line of the code.

# %% [markdown]
# ## Problem 2 (1 point)
#
# Write a function that reads file "ice_class_raw_data.csv", and loads its data to a dataframe.  Then create a pair-plot for all variables against each other for CAP=0 (blue color) and then superimposed for CAP=1 (red) as shown in figure below. You need write annotation and explanation for each line of the code. Hint=Seaborn PairGrid
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 3 (1 point)
#
# Create a function that simulates and return the estimated probability that six rolls of a fair six-sided die all give different numbers. You need to use computer to simulate N trials, and return the estimated probability as a float number. Hint: np.sort, np.diff, np.all

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
import pandas as pd
import numpy as np
def myfunction(N):
    
    ### BEGIN SOLUTION
    rolls=6
    trials=N
    temp = np.random.randint(1,7,[rolls,trials])
    temp1=np.sort(temp,axis=0)
    temp2=np.diff(temp1,axis=0)
    res=np.mean(np.all(temp2==1,axis=0))
    return res

    ### END SOLUTION

# %%
from math import factorial
res=myfunction(10000)
'''sorry, my testing code is hided this time!'''
### BEGIN HIDDEN TESTS
assert abs(res-factorial(6)/6**6)<0.002
### END HIDDEN TESTS
